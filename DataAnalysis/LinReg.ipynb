# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Enable inline plotting (if using Jupyter Notebook)
# %matplotlib inline

# Read the CSV file
data = pd.read_csv('NONseasonticket.csv')

# Define predictor columns
predictors = ['FanSegment', 'DistanceToArena', 'BasketballPropensity', 'SocialMediaEngagement']

# Extract predictor data
X = data[predictors].copy()

# Convert numeric columns (if necessary)
X['DistanceToArena'] = pd.to_numeric(X['DistanceToArena'], errors='coerce')
X['BasketballPropensity'] = pd.to_numeric(X['BasketballPropensity'], errors='coerce')

# One-hot encode the categorical predictors: FanSegment and SocialMediaEngagement
X = pd.get_dummies(X, columns=['FanSegment', 'SocialMediaEngagement'], drop_first=True)

# Fill missing values in predictors with their respective means
X.fillna(X.mean(), inplace=True)

# %%
# Define target column for this regression
target = "A Games"

# Convert the target column to numeric and drop missing values
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

# Initialize and fit the linear regression model
model = LinearRegression()
model.fit(X_valid, y_valid)

# Make predictions
y_pred = model.predict(X_valid)

# Plot actual vs predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

# Print regression coefficients and intercept
print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for A Games :
# DistanceToArena                 0.000024
# BasketballPropensity            0.000451
# FanSegment_B                    0.125753
# FanSegment_C                    0.006318
# FanSegment_D                    0.077829
# FanSegment_E                    0.168653
# FanSegment_F                    0.523089
# FanSegment_G                    2.787508
# FanSegment_Limited Data         0.169369
# SocialMediaEngagement_Low      -0.004560
# SocialMediaEngagement_Medium    0.023313
# dtype: float64
# Intercept: 0.10463826201961218

# %%
# Define target column for this regression
target = "B Games"

# Convert the target column to numeric and drop missing values
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

# Initialize and fit the linear regression model
model = LinearRegression()
model.fit(X_valid, y_valid)

# Make predictions
y_pred = model.predict(X_valid)

# Plot actual vs predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

# Print regression coefficients and intercept
print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for B Games :
# DistanceToArena                 0.000089
# BasketballPropensity            0.000084
# FanSegment_B                    0.069181
# FanSegment_C                    0.044272
# FanSegment_D                    0.076986
# FanSegment_E                    0.030906
# FanSegment_F                    0.624401
# FanSegment_G                    5.028996
# FanSegment_Limited Data         0.002943
# SocialMediaEngagement_Low       0.079455
# SocialMediaEngagement_Medium    0.073660
# dtype: float64
# Intercept: 0.5706702291941645

# %%
target = "C Games"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for C Games :
# DistanceToArena                -0.000150
# BasketballPropensity            0.000331
# FanSegment_B                   -0.027806
# FanSegment_C                   -0.091587
# FanSegment_D                    0.057538
# FanSegment_E                    0.099455
# FanSegment_F                    1.080749
# FanSegment_G                    5.456800
# FanSegment_Limited Data         0.026669
# SocialMediaEngagement_Low      -0.013704
# SocialMediaEngagement_Medium   -0.066328
# dtype: float64
# Intercept: 1.2001693588761388

# %%
target = "D Games"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for D Games :
# DistanceToArena                  0.000673
# BasketballPropensity            -0.000414
# FanSegment_B                     0.072514
# FanSegment_C                    -0.202010
# FanSegment_D                     0.194845
# FanSegment_E                     0.244963
# FanSegment_F                     1.019804
# FanSegment_G                    13.427700
# FanSegment_Limited Data          0.023639
# SocialMediaEngagement_Low        0.075136
# SocialMediaEngagement_Medium     0.176044
# dtype: float64
# Intercept: 1.996803614552027

# %%
target = "Weekend Games"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for Weekend Games :
# DistanceToArena                -0.000212
# BasketballPropensity            0.000695
# FanSegment_B                    0.129291
# FanSegment_C                   -0.203635
# FanSegment_D                    0.015236
# FanSegment_E                    0.244230
# FanSegment_F                    1.372846
# FanSegment_G                    7.031721
# FanSegment_Limited Data         0.063498
# SocialMediaEngagement_Low      -0.003685
# SocialMediaEngagement_Medium   -0.017130
# dtype: float64
# Intercept: 1.201716454967968

# %%
target = "Weekday Games"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for Weekday Games :
# DistanceToArena                  0.000848
# BasketballPropensity            -0.000242
# FanSegment_B                     0.110351
# FanSegment_C                    -0.039373
# FanSegment_D                     0.391962
# FanSegment_E                     0.299748
# FanSegment_F                     1.875198
# FanSegment_G                    19.669283
# FanSegment_Limited Data          0.159122
# SocialMediaEngagement_Low        0.140013
# SocialMediaEngagement_Medium     0.223819
# dtype: float64
# Intercept: 2.6705650096739766

# %%
target = "Promotional Games"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for Promotional Games :
# DistanceToArena                 0.000225
# BasketballPropensity           -0.000364
# FanSegment_B                    0.012413
# FanSegment_C                   -0.149771
# FanSegment_D                   -0.071184
# FanSegment_E                    0.098460
# FanSegment_F                    0.398162
# FanSegment_G                    5.680261
# FanSegment_Limited Data        -0.047789
# SocialMediaEngagement_Low       0.064359
# SocialMediaEngagement_Medium    0.074656
# dtype: float64
# Intercept: 1.2046530953754968

# %%
target = "Non Promo Games"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for Non Promo Games :
# DistanceToArena                  0.000411
# BasketballPropensity             0.000817
# FanSegment_B                     0.227229
# FanSegment_C                    -0.093237
# FanSegment_D                     0.478382
# FanSegment_E                     0.445517
# FanSegment_F                     2.849883
# FanSegment_G                    21.020743
# FanSegment_Limited Data          0.270409
# SocialMediaEngagement_Low        0.071968
# SocialMediaEngagement_Medium     0.132032
# dtype: float64
# Intercept: 2.6676283692664464

# %%
target = "A + Weekend + Promo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for A + Weekend + Promo :
# DistanceToArena                 0.0
# BasketballPropensity            0.0
# FanSegment_B                    0.0
# FanSegment_C                    0.0
# FanSegment_D                    0.0
# FanSegment_E                    0.0
# FanSegment_F                    0.0
# FanSegment_G                    0.0
# FanSegment_Limited Data         0.0
# SocialMediaEngagement_Low       0.0
# SocialMediaEngagement_Medium    0.0
# dtype: float64
# Intercept: 0.0

# %%
target = "A + Weekend + nonPromo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for A + Weekend + nonPromo :
# DistanceToArena                 0.000002
# BasketballPropensity            0.000255
# FanSegment_B                    0.046966
# FanSegment_C                   -0.032545
# FanSegment_D                    0.024729
# FanSegment_E                    0.042169
# FanSegment_F                    0.235748
# FanSegment_G                    1.245648
# FanSegment_Limited Data         0.082918
# SocialMediaEngagement_Low      -0.003200
# SocialMediaEngagement_Medium    0.010063
# dtype: float64
# Intercept: 0.056589791227847686

# %%
target = "A + Weekday + Promo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for A + Weekday + Promo :
# DistanceToArena                 0.0
# BasketballPropensity            0.0
# FanSegment_B                    0.0
# FanSegment_C                    0.0
# FanSegment_D                    0.0
# FanSegment_E                    0.0
# FanSegment_F                    0.0
# FanSegment_G                    0.0
# FanSegment_Limited Data         0.0
# SocialMediaEngagement_Low       0.0
# SocialMediaEngagement_Medium    0.0
# dtype: float64
# Intercept: 0.0

# %%
target = "A + Weekday + nonPromo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for A + Weekday + nonPromo :
# DistanceToArena                 0.000021
# BasketballPropensity            0.000197
# FanSegment_B                    0.078788
# FanSegment_C                    0.038863
# FanSegment_D                    0.053100
# FanSegment_E                    0.126484
# FanSegment_F                    0.287341
# FanSegment_G                    1.541860
# FanSegment_Limited Data         0.086450
# SocialMediaEngagement_Low      -0.001361
# SocialMediaEngagement_Medium    0.013250
# dtype: float64
# Intercept: 0.04804847079176497

# %%
target = "B + Weekend + Promo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for B + Weekend + Promo :
# DistanceToArena                -0.000023
# BasketballPropensity           -0.000011
# FanSegment_B                    0.007698
# FanSegment_C                    0.000922
# FanSegment_D                   -0.006026
# FanSegment_E                    0.018811
# FanSegment_F                    0.076059
# FanSegment_G                    0.431545
# FanSegment_Limited Data         0.002000
# SocialMediaEngagement_Low       0.014325
# SocialMediaEngagement_Medium    0.017929
# dtype: float64
# Intercept: 0.04218775460350857

# %%
target = "B + Weekend + nonPromo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for B + Weekend + nonPromo :
# DistanceToArena                -0.000066
# BasketballPropensity            0.000074
# FanSegment_B                    0.061599
# FanSegment_C                    0.005263
# FanSegment_D                    0.005162
# FanSegment_E                    0.073820
# FanSegment_F                    0.241671
# FanSegment_G                    1.052928
# FanSegment_Limited Data         0.010834
# SocialMediaEngagement_Low       0.005335
# SocialMediaEngagement_Medium    0.005575
# dtype: float64
# Intercept: 0.16921476496359128

# %%
target = "B + Weekday + Promo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for B + Weekday + Promo :
# DistanceToArena                 0.000030
# BasketballPropensity           -0.000083
# FanSegment_B                    0.006066
# FanSegment_C                    0.021473
# FanSegment_D                    0.005548
# FanSegment_E                    0.001578
# FanSegment_F                   -0.034380
# FanSegment_G                    0.145335
# FanSegment_Limited Data        -0.008059
# SocialMediaEngagement_Low       0.018091
# SocialMediaEngagement_Medium    0.006625
# dtype: float64
# Intercept: 0.12319197895929432

# %%
target = "B + Weekday + nonPromo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for B + Weekday + nonPromo :
# DistanceToArena                 0.000149
# BasketballPropensity            0.000104
# FanSegment_B                   -0.006183
# FanSegment_C                    0.016615
# FanSegment_D                    0.072303
# FanSegment_E                   -0.063302
# FanSegment_F                    0.341051
# FanSegment_G                    3.399188
# FanSegment_Limited Data        -0.001832
# SocialMediaEngagement_Low       0.041705
# SocialMediaEngagement_Medium    0.043531
# dtype: float64
# Intercept: 0.2360757306677708

# %%
target = "C + Weekend + Promo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for C + Weekend + Promo :
# DistanceToArena                 0.000020
# BasketballPropensity           -0.000011
# FanSegment_B                   -0.005255
# FanSegment_C                   -0.036296
# FanSegment_D                    0.009233
# FanSegment_E                   -0.006110
# FanSegment_F                   -0.005294
# FanSegment_G                    0.281794
# FanSegment_Limited Data        -0.036403
# SocialMediaEngagement_Low       0.016198
# SocialMediaEngagement_Medium   -0.003709
# dtype: float64
# Intercept: 0.08648757862474689

# %%
target = "C + Weekend + nonPromo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for C + Weekend + nonPromo :
# DistanceToArena                -0.000115
# BasketballPropensity            0.000199
# FanSegment_B                    0.005035
# FanSegment_C                   -0.047460
# FanSegment_D                    0.020928
# FanSegment_E                    0.080113
# FanSegment_F                    0.665206
# FanSegment_G                    2.686838
# FanSegment_Limited Data         0.023000
# SocialMediaEngagement_Low      -0.047126
# SocialMediaEngagement_Medium   -0.030180
# dtype: float64
# Intercept: 0.5923529047257622

# %%
target = "C + Weekend + nonPromo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for C + Weekend + nonPromo :
# DistanceToArena                -0.000115
# BasketballPropensity            0.000199
# FanSegment_B                    0.005035
# FanSegment_C                   -0.047460
# FanSegment_D                    0.020928
# FanSegment_E                    0.080113
# FanSegment_F                    0.665206
# FanSegment_G                    2.686838
# FanSegment_Limited Data         0.023000
# SocialMediaEngagement_Low      -0.047126
# SocialMediaEngagement_Medium   -0.030180
# dtype: float64
# Intercept: 0.5923529047257622

# %%
target = "C + Weekday + Promo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for C + Weekday + Promo :
# DistanceToArena                 0.000002
# BasketballPropensity           -0.000056
# FanSegment_B                   -0.010708
# FanSegment_C                   -0.023047
# FanSegment_D                   -0.019718
# FanSegment_E                   -0.023421
# FanSegment_F                   -0.043689
# FanSegment_G                    0.025329
# FanSegment_Limited Data        -0.017363
# SocialMediaEngagement_Low       0.006021
# SocialMediaEngagement_Medium   -0.006543
# dtype: float64
# Intercept: 0.09722326776558891

# %%
target = "C + Weekday + nonPromo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for C + Weekday + nonPromo :
# DistanceToArena                -0.000057
# BasketballPropensity            0.000200
# FanSegment_B                   -0.016878
# FanSegment_C                    0.015216
# FanSegment_D                    0.047095
# FanSegment_E                    0.048874
# FanSegment_F                    0.464526
# FanSegment_G                    2.462840
# FanSegment_Limited Data         0.057434
# SocialMediaEngagement_Low       0.011203
# SocialMediaEngagement_Medium   -0.025896
# dtype: float64
# Intercept: 0.42410560776004114

# %%
target = "D + Weekend + Promo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for D + Weekend + Promo :
# DistanceToArena                 0.000014
# BasketballPropensity           -0.000124
# FanSegment_B                    0.008504
# FanSegment_C                   -0.020537
# FanSegment_D                   -0.034884
# FanSegment_E                    0.023123
# FanSegment_F                   -0.000612
# FanSegment_G                    0.502035
# FanSegment_Limited Data        -0.073302
# SocialMediaEngagement_Low       0.009095
# SocialMediaEngagement_Medium   -0.009699
# dtype: float64
# Intercept: 0.21907628561957296

# %%
target = "D + Weekend + nonPromo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for D + Weekend + nonPromo :
# DistanceToArena                -0.000044
# BasketballPropensity            0.000314
# FanSegment_B                    0.004743
# FanSegment_C                   -0.072982
# FanSegment_D                   -0.003906
# FanSegment_E                    0.012303
# FanSegment_F                    0.160069
# FanSegment_G                    0.830933
# FanSegment_Limited Data         0.054450
# SocialMediaEngagement_Low       0.001688
# SocialMediaEngagement_Medium   -0.007108
# dtype: float64
# Intercept: 0.03580737520293886

# %%
target = "D + Weekday + Promo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for D + Weekday + Promo :
# DistanceToArena                 0.000183
# BasketballPropensity           -0.000079
# FanSegment_B                    0.006107
# FanSegment_C                   -0.092285
# FanSegment_D                   -0.025337
# FanSegment_E                    0.084480
# FanSegment_F                    0.406078
# FanSegment_G                    4.294223
# FanSegment_Limited Data         0.085337
# SocialMediaEngagement_Low       0.000630
# SocialMediaEngagement_Medium    0.070054
# dtype: float64
# Intercept: 0.6364862298027884

# %%
target = "D + Weekday + nonPromo"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for D + Weekday + nonPromo :
# DistanceToArena                 0.000520
# BasketballPropensity           -0.000524
# FanSegment_B                    0.053160
# FanSegment_C                   -0.016207
# FanSegment_D                    0.258972
# FanSegment_E                    0.125056
# FanSegment_F                    0.454270
# FanSegment_G                    7.800508
# FanSegment_Limited Data        -0.042845
# SocialMediaEngagement_Low       0.063723
# SocialMediaEngagement_Medium    0.122798
# dtype: float64
# Intercept: 1.1054337239267287

# %%
target = "NumGamesAttend"
y = pd.to_numeric(data[target], errors='coerce')
valid_idx = y.notnull()
X_valid = X[valid_idx]
y_valid = y[valid_idx]

model = LinearRegression()
model.fit(X_valid, y_valid)
y_pred = model.predict(X_valid)

plt.figure(figsize=(8,6))
plt.scatter(y_valid, y_pred, alpha=0.7, edgecolor='k')
plt.xlabel('Actual ' + target)
plt.ylabel('Predicted ' + target)
plt.title('Linear Regression for ' + target)
min_val = min(y_valid.min(), y_pred.min())
max_val = max(y_valid.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

print("Regression coefficients for", target, ":")
print(pd.Series(model.coef_, index=X.columns))
print("Intercept:", model.intercept_)
# Out:
# Regression coefficients for NumGamesAttend :
# DistanceToArena                -0.000322
# BasketballPropensity            0.000767
# FanSegment_B                    0.142646
# FanSegment_C                    0.137710
# FanSegment_D                    0.199779
# FanSegment_E                    0.282660
# FanSegment_F                    0.703041
# FanSegment_G                    4.726887
# FanSegment_Limited Data        -0.122749
# SocialMediaEngagement_Low       0.022202
# SocialMediaEngagement_Medium    0.005502
# dtype: float64
# Intercept: 0.9624332520096416
